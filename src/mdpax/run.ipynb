# %%
from environment import *
from dqn_agent import Agent
import jax
from jax import jit, random, numpy as jnp
from gymnasium import spaces
import os
import time


@jit
def example_reward_function(state, goal_state):
    """Define your reward logic here."""
    is_goal = jnp.all(state == goal_state)
    current_distance = jnp.linalg.norm(state - goal_state)
    total_distance = jnp.sqrt(2)
    percentage = current_distance / total_distance
    distance_reward = jnp.where(percentage < 0.33, -1, jnp.where(percentage < 0.66, -2, -3))
    reward = jnp.where(is_goal, 15.0, distance_reward)
    return reward


def example_transition_function(state, action, state_space_shape, _key):
    """Define your state transition logic here."""
    x, y = state
    _key, subkey = random.split(_key)

    def magic(key):
        # return random.uniform(key, minval=-1, maxval=1, shape=(2,), dtype=dtype)
        return random.uniform(key, (2,), minval=-1, maxval=1, dtype=jnp.float32)

    def action_one(_):
        return x + y

    def action_two(_):
        return jnp.abs(x - y)

    def action_three(_):
        return x / y

    def action_four(_):
        return y / x

    fp_key = jax.lax.switch(action, [action_one, action_two, action_three, action_four], None)
    x, y = magic(subkey) * fp_key
    return jnp.array([x, y], dtype=jnp.float32)


# ENV SETTINGS

def setup_environment():
        
    dimensions = env_min, env_max = -jnp.inf, jnp.inf
    dtype = jnp.float32

    state_space = spaces.Box(low=env_min, high=max(env_min, env_max), shape=(1, len(dimensions)), dtype=dtype)

    action_space_n = 4
    action_space = spaces.Discrete(action_space_n)

    target_state = jnp.array([0.0, 0.0], dtype=dtype)
    initial_state = jnp.array([-1.0, 1.0], dtype=dtype)

    seed = 0

    config = EnvironmentConfig(
        seed=seed,
        state_space=state_space,
        action_space=action_space,
        initial_state=initial_state,
        target_state=target_state,
        reward_function=jit(example_reward_function),
        transition_function=jit(example_transition_function),
    )
    return create_environment(config)

# %%
def save_agent(agent, output_dir, episode):
    filename = os.path.join(output_dir, f"agent_{episode}.pkl")
    agent.save(filename)
    print(f"\n\n {episode} Episodes: saved model to {filename}\n\n")

def load_latest_agent(agent, output_dir):
    files = [f for f in os.listdir(output_dir) if f.startswith("agent_") and f.endswith(".pkl")]
    if not files:
        print("No saved agents found.")
        return False

    latest_file = max(files, key=lambda f: int(f.split('_')[1].split('.')[0]))
    latest_file_path = os.path.join(output_dir, latest_file)
    
    confirmation = input(f"Do you want to load the latest agent from {latest_file_path}? (y/n): ")
    if confirmation.lower() != 'y':
        return False

    agent.load(latest_file_path)
    print(f"Agent loaded from {latest_file_path}")
    return True

# %%
def train_agent(agent, env, num_episodes, num_iterations, batch_size, output_dir):
    start_time = time.time()
    global_steps = 0
    global_rewards = []
    
    mean_episode_reward = 0
    for episode in range(num_episodes):
        state, _, _ = env.reset()
        episode_reward = 0

        for t in range(num_iterations):
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            global_steps += 1
            episode_reward += reward
            agent.remember(state, action, reward, next_state, done)
            state = next_state

            if done or t == (num_iterations - 1):
                break
        elapsed_time = time.time() - start_time
        hours, rem = divmod(elapsed_time, 3600)
        minutes, seconds = divmod(rem, 60)
        global_rewards.append(episode_reward)
        mean_episode_reward = jnp.mean(jnp.array(global_rewards)) if global_rewards else 0.0
        # make mean_episode_reward a scalar
        if len(agent.memory) > batch_size:
            loss = agent.replay(batch_size)
        else:
            loss = 0.0
            
        print(f"Time: {int(hours):02}h {int(minutes):02}m {int(seconds):02}s, Episode: {episode}, Steps: {global_steps}, epr: {float(mean_episode_reward):.3}, Loss: {float(loss):.3} Score: {episode_reward}, Done: {done}")
        
        if episode % 10 == 0:
            save_agent(agent, output_dir, episode)

# %%
if __name__ == "__main__":
    
    output_dir = "results/first_try"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        
    env = setup_environment()
    state_size = len(env.state_space.shape)
    action_size = env.action_space.n


    agent = Agent(state_size, action_size)
    
    if not load_latest_agent(agent, output_dir):
        agent = Agent(state_size, action_size)

    batch_size = 32  # increase by powers of 2
    num_episodes = 5000  # Number of episodes to simulate
    num_iterations = 10  # Number of steps per episode
    
    train_agent(agent, env, num_episodes, num_iterations, batch_size, output_dir)
# Out:
# Time: 00h 00m 00s, Episode: 0, Steps: 10, epr: -18.0, Loss: 0.0 Score: -18.0, Done: False
#
#
#  0 Episodes: saved model to results/gen1/agent_0.pkl
#
#
# Time: 00h 00m 00s, Episode: 1, Steps: 20, epr: -20.5, Loss: 0.0 Score: -23.0, Done: False
# Time: 00h 00m 00s, Episode: 2, Steps: 30, epr: -17.3, Loss: 0.0 Score: -11.0, Done: False
# Time: 00h 00m 00s, Episode: 3, Steps: 40, epr: -18.5, Loss: 3.78 Score: -22.0, Done: False
# Time: 00h 00m 01s, Episode: 4, Steps: 50, epr: -17.6, Loss: 8.31 Score: -14.0, Done: False
# Time: 00h 00m 01s, Episode: 5, Steps: 60, epr: -17.3, Loss: 4.0 Score: -16.0, Done: False
# Time: 00h 00m 01s, Episode: 6, Steps: 70, epr: -17.0, Loss: 3.08 Score: -15.0, Done: False
# Time: 00h 00m 01s, Episode: 7, Steps: 80, epr: -18.0, Loss: 7.72 Score: -25.0, Done: False
# Time: 00h 00m 01s, Episode: 8, Steps: 90, epr: -17.9, Loss: 3.72 Score: -17.0, Done: False
# Time: 00h 00m 01s, Episode: 9, Steps: 100, epr: -17.9, Loss: 3.46 Score: -18.0, Done: False
# Time: 00h 00m 02s, Episode: 10, Steps: 110, epr: -17.6, Loss: 2.82 Score: -15.0, Done: False
#
#
#  10 Episodes: saved model to results/gen1/agent_10.pkl
#
#
# Time: 00h 00m 02s, Episode: 11, Steps: 120, epr: -18.2, Loss: 3.86 Score: -25.0, Done: False
# Time: 00h 00m 02s, Episode: 12, Steps: 130, epr: -17.8, Loss: 3.32 Score: -12.0, Done: False
# Time: 00h 00m 02s, Episode: 13, Steps: 140, epr: -17.6, Loss: 3.6 Score: -15.0, Done: False
# Time: 00h 00m 02s, Episode: 14, Steps: 150, epr: -17.7, Loss: 4.73 Score: -20.0, Done: False
# Time: 00h 00m 02s, Episode: 15, Steps: 160, epr: -17.8, Loss: 2.43 Score: -18.0, Done: False
# Time: 00h 00m 02s, Episode: 16, Steps: 170, epr: -17.8, Loss: 3.23 Score: -18.0, Done: False
# Time: 00h 00m 02s, Episode: 17, Steps: 180, epr: -17.7, Loss: 3.62 Score: -17.0, Done: False
# Time: 00h 00m 03s, Episode: 18, Steps: 190, epr: -17.9, Loss: 3.12 Score: -21.0, Done: False
# Time: 00h 00m 03s, Episode: 19, Steps: 200, epr: -18.2, Loss: 4.21 Score: -25.0, Done: False
# Time: 00h 00m 03s, Episode: 20, Steps: 210, epr: -18.2, Loss: 4.1 Score: -18.0, Done: False
#
#
#  20 Episodes: saved model to results/gen1/agent_20.pkl
#
#
# Time: 00h 00m 03s, Episode: 21, Steps: 220, epr: -18.3, Loss: 4.41 Score: -20.0, Done: False
# Time: 00h 00m 03s, Episode: 22, Steps: 230, epr: -18.6, Loss: 5.26 Score: -24.0, Done: False
# Time: 00h 00m 03s, Episode: 23, Steps: 240, epr: -18.3, Loss: 4.48 Score: -13.0, Done: False
# Time: 00h 00m 03s, Episode: 24, Steps: 250, epr: -18.3, Loss: 5.25 Score: -17.0, Done: False
# Time: 00h 00m 03s, Episode: 25, Steps: 260, epr: -18.2, Loss: 4.04 Score: -16.0, Done: False
# Time: 00h 00m 04s, Episode: 26, Steps: 270, epr: -18.2, Loss: 4.55 Score: -18.0, Done: False
# Time: 00h 00m 04s, Episode: 27, Steps: 280, epr: -18.4, Loss: 5.55 Score: -24.0, Done: False
# Time: 00h 00m 04s, Episode: 28, Steps: 290, epr: -18.2, Loss: 4.85 Score: -14.0, Done: False
# Time: 00h 00m 04s, Episode: 29, Steps: 300, epr: -18.2, Loss: 4.65 Score: -17.0, Done: False
# Time: 00h 00m 04s, Episode: 30, Steps: 310, epr: -18.3, Loss: 4.34 Score: -22.0, Done: False
#
#
#  30 Episodes: saved model to results/gen1/agent_30.pkl
#
#
# Time: 00h 00m 04s, Episode: 31, Steps: 320, epr: -18.6, Loss: 3.77 Score: -26.0, Done: False
# Time: 00h 00m 04s, Episode: 32, Steps: 330, epr: -18.5, Loss: 3.63 Score: -15.0, Done: False
# Time: 00h 00m 04s, Episode: 33, Steps: 340, epr: -18.2, Loss: 4.25 Score: -11.0, Done: False
# Time: 00h 00m 05s, Episode: 34, Steps: 350, epr: -18.3, Loss: 3.59 Score: -20.0, Done: False
# Time: 00h 00m 05s, Episode: 35, Steps: 360, epr: -18.3, Loss: 3.57 Score: -20.0, Done: False
# Time: 00h 00m 05s, Episode: 36, Steps: 370, epr: -18.2, Loss: 3.4 Score: -15.0, Done: False
# Time: 00h 00m 05s, Episode: 37, Steps: 380, epr: -18.2, Loss: 2.73 Score: -17.0, Done: False
# Time: 00h 00m 05s, Episode: 38, Steps: 390, epr: -18.1, Loss: 3.54 Score: -14.0, Done: False
# Time: 00h 00m 05s, Episode: 39, Steps: 400, epr: -17.9, Loss: 3.7 Score: -11.0, Done: False
# Time: 00h 00m 05s, Episode: 40, Steps: 410, epr: -17.9, Loss: 3.48 Score: -18.0, Done: False
#
#
#  40 Episodes: saved model to results/gen1/agent_40.pkl
#
#
# Time: 00h 00m 05s, Episode: 41, Steps: 420, epr: -17.8, Loss: 5.07 Score: -14.0, Done: False
# Time: 00h 00m 06s, Episode: 42, Steps: 430, epr: -17.7, Loss: 3.98 Score: -11.0, Done: False
# Time: 00h 00m 06s, Episode: 43, Steps: 440, epr: -17.6, Loss: 4.39 Score: -16.0, Done: False
# Time: 00h 00m 06s, Episode: 44, Steps: 450, epr: -17.6, Loss: 2.13 Score: -18.0, Done: False
# Time: 00h 00m 06s, Episode: 45, Steps: 460, epr: -17.6, Loss: 3.8 Score: -17.0, Done: False
# Time: 00h 00m 06s, Episode: 46, Steps: 470, epr: -17.6, Loss: 5.31 Score: -17.0, Done: False
# Time: 00h 00m 06s, Episode: 47, Steps: 480, epr: -17.6, Loss: 2.85 Score: -15.0, Done: False
# Time: 00h 00m 06s, Episode: 48, Steps: 490, epr: -17.5, Loss: 3.23 Score: -13.0, Done: False
# Time: 00h 00m 07s, Episode: 49, Steps: 500, epr: -17.4, Loss: 3.2 Score: -13.0, Done: False
# Time: 00h 00m 07s, Episode: 50, Steps: 510, epr: -17.3, Loss: 2.52 Score: -13.0, Done: False
#
#
#  50 Episodes: saved model to results/gen1/agent_50.pkl
#
#
# Time: 00h 00m 07s, Episode: 51, Steps: 520, epr: -17.4, Loss: 3.02 Score: -22.0, Done: False
# Time: 00h 00m 07s, Episode: 52, Steps: 530, epr: -17.4, Loss: 1.72 Score: -19.0, Done: False
# Time: 00h 00m 07s, Episode: 53, Steps: 540, epr: -17.3, Loss: 2.65 Score: -11.0, Done: False
# Time: 00h 00m 07s, Episode: 54, Steps: 550, epr: -17.2, Loss: 4.04 Score: -14.0, Done: False
# Time: 00h 00m 08s, Episode: 55, Steps: 560, epr: -17.2, Loss: 4.88 Score: -17.0, Done: False
# Time: 00h 00m 08s, Episode: 56, Steps: 570, epr: -17.2, Loss: 8.49 Score: -16.0, Done: False
# Time: 00h 00m 08s, Episode: 57, Steps: 580, epr: -17.2, Loss: 6.96 Score: -14.0, Done: False
# Time: 00h 00m 08s, Episode: 58, Steps: 590, epr: -17.3, Loss: 3.91 Score: -27.0, Done: False
# Time: 00h 00m 09s, Episode: 59, Steps: 600, epr: -17.4, Loss: 2.58 Score: -20.0, Done: False
# Time: 00h 00m 09s, Episode: 60, Steps: 610, epr: -17.4, Loss: 2.34 Score: -17.0, Done: False
#
#
#  60 Episodes: saved model to results/gen1/agent_60.pkl
#
#
# Time: 00h 00m 09s, Episode: 61, Steps: 620, epr: -17.3, Loss: 2.96 Score: -12.0, Done: False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 21
#      18 num_episodes = 5000  # Number of episodes to simulate
#      19 num_iterations = 10  # Number of steps per episode
# ---> 21 train_agent(agent, env, num_episodes, num_iterations, batch_size, output_dir)
#
# Cell In[5], line 28, in train_agent(agent, env, num_episodes, num_iterations, batch_size, output_dir)
#      26 # make mean_episode_reward a scalar
#      27 if len(agent.memory) > batch_size:
# ---> 28     loss = agent.replay(batch_size)
#      29 else:
#      30     loss = 0.0
#
# File /home/library/workspace/mlos/gym/0_mdpax/dqn_agent.py:97, in Agent.replay(self, batch_size)
#      95 futures = jnp.max(self.model.apply(self.state.params, next_states), axis=-1)
#      96 # compute the target q values
# ---> 97 target_q_values = compute_target_q_values(rewards, self.gamma, futures, dones)
#      99 # define the loss function
#     100 def loss_fn(params, state, action, target):
#
#     [... skipping hidden 1 frame]
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:327, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     325 @api_boundary
#     326 def cache_miss(*args, **kwargs):
# --> 327   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     328       jit_info, *args, **kwargs)
#     329   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     330   pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:185, in _python_pjit_helper(jit_info, *args, **kwargs)
#     182   args_flat = [*init_states, *args_flat]
#     184 try:
# --> 185   out_flat = pjit_p.bind(*args_flat, **params)
#     186 except pxla.DeviceAssignmentMismatchError as e:
#     187   fails, = e.args
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/core.py:2834, in AxisPrimitive.bind(self, *args, **params)
#    2830 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2831                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2832 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833              else axis_main.with_cur_sublevel())
# -> 2834 return self.bind_with_trace(top_trace, args, params)
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/core.py:921, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     919   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     920 else:
# --> 921   return primitive.impl(*tracers, **params)
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:1635, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1632 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1633 has_explicit_sharding = _pjit_explicit_sharding(
#    1634     in_shardings, out_shardings, None, None)
# -> 1635 return xc._xla.pjit(
#    1636     name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1637     tree_util.dispatch_registry,
#    1638     lambda x, sharding: pxla.shard_args([sharding], [x])[0],
#    1639     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:1614, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1613 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1614   out_flat, compiled = _pjit_call_impl_python(
#    1615       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1616       out_shardings=out_shardings, in_layouts=in_layouts,
#    1617       out_layouts=out_layouts, resource_env=resource_env,
#    1618       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1619       inline=inline)
#    1620   pgle_profiler = _read_pgle_profiler(jaxpr)
#    1621   fastpath_data = _get_fastpath_data(
#    1622       compiled, tree_structure(out_flat), args, out_flat, [], jaxpr.effects,
#    1623       jaxpr.consts, None, pgle_profiler)
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:1536, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1531     compile_options = {'fdo_profile': fdo_profile}
#    1533 # TODO(patrios): Do not pass mutable profile session through cached lowering
#    1534 # chain. Instead we need to move profilers dictionary to pxla module and use
#    1535 # module as key. Right now we can't do that since there is no way to evict _pjit_lower_cached cache for in PGLE mode.
# -> 1536 compiled = _resolve_and_lower(
#    1537     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1538     out_shardings=out_shardings, in_layouts=in_layouts,
#    1539     out_layouts=out_layouts, resource_env=resource_env,
#    1540     donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1541     inline=inline, lowering_platforms=None,
#    1542     lowering_parameters=mlir.LoweringParameters(),
#    1543     pgle_profiler=pgle_profiler
#    1544 ).compile(compile_options)
#    1546 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1547 # This check is expensive so only do it if enable_checks is on.
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:1503, in _resolve_and_lower(args, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, lowering_platforms, lowering_parameters, pgle_profiler)
#    1498 in_shardings = _resolve_in_shardings(
#    1499     args, in_shardings, out_shardings,
#    1500     resource_env.physical_mesh if resource_env is not None else None)
#    1501 in_layouts = _resolve_in_layouts(args, in_layouts, in_shardings,
#    1502                                  jaxpr.in_avals)
# -> 1503 lowered = _pjit_lower(
#    1504     jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env,
#    1505     donated_invars, name, keep_unused, inline,
#    1506     lowering_platforms=lowering_platforms,
#    1507     lowering_parameters=lowering_parameters,
#    1508     pgle_profiler=pgle_profiler)
#    1509 return lowered
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:1645, in _pjit_lower(*args, **kwargs)
#    1644 def _pjit_lower(*args, **kwargs):
# -> 1645   return _pjit_lower_cached(*args, **kwargs)
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:1685, in _pjit_lower_cached(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, lowering_platforms, lowering_parameters, pgle_profiler)
#    1678   return pxla.lower_mesh_computation(
#    1679     jaxpr, api_name, name, mesh,
#    1680     in_shardings, out_shardings, donated_invars,
#    1681     True, jaxpr.in_avals, tiling_method=None,
#    1682     lowering_platforms=lowering_platforms,
#    1683     lowering_parameters=lowering_parameters)
#    1684 else:
# -> 1685   return pxla.lower_sharding_computation(
#    1686       jaxpr, api_name, name, in_shardings, out_shardings,
#    1687       in_layouts, out_layouts, tuple(donated_invars),
#    1688       keep_unused=keep_unused, inline=inline,
#    1689       devices_from_context=(
#    1690           None if mesh is None or mesh.empty else list(mesh.devices.flat)),
#    1691       lowering_platforms=lowering_platforms,
#    1692       lowering_parameters=lowering_parameters,
#    1693       pgle_profiler=pgle_profiler)
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:2253, in lower_sharding_computation(closed_jaxpr, api_name, fun_name, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, keep_unused, inline, devices_from_context, lowering_platforms, lowering_parameters, pgle_profiler)
#    2248 semantic_out_shardings = SemanticallyEqualShardings(
#    2249     out_shardings, global_out_avals)  # type: ignore
#    2250 prim_requires_devices = dispatch.jaxpr_has_prim_requiring_devices(jaxpr)
#    2252 (module, keepalive, host_callbacks, unordered_effects, ordered_effects,
# -> 2253  nreps, tuple_args, shape_poly_state) = _cached_lowering_to_hlo(
#    2254      closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings,
#    2255      semantic_out_shardings, in_layouts, out_layouts, len(da_object),
#    2256      tuple(da_object) if prim_requires_devices else None, donated_invars,
#    2257      name_stack, all_default_mem_kind, inout_aliases,
#    2258      propagated_out_mem_kinds, platforms,
#    2259      lowering_parameters=lowering_parameters)
#    2261 # backend and device_assignment is passed through to MeshExecutable because
#    2262 # if keep_unused=False and all in_shardings are pruned, then there is no way
#    2263 # to get the device_assignment and backend. So pass it to MeshExecutable
#    2264 # because we calculate the device_assignment and backend before in_shardings,
#    2265 # etc are pruned.
#    2266 return MeshComputation(
#    2267     str(name_stack),
#    2268     module,
#    (...)
#    2292     all_args_info=all_args_info,
#    2293     pgle_profiler=pgle_profiler)
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:2017, in _cached_lowering_to_hlo(closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings, semantic_out_shardings, in_layouts, out_layouts, num_devices, device_assignment, donated_invars, name_stack, all_default_mem_kind, inout_aliases, propagated_out_mem_kinds, platforms, lowering_parameters)
#    2013 ordered_effects = list(effects.ordered_effects.filter_in(closed_jaxpr.effects))
#    2014 with dispatch.log_elapsed_time(
#    2015       "Finished jaxpr to MLIR module conversion {fun_name} in {elapsed_time} sec",
#    2016       fun_name=str(name_stack), event=dispatch.JAXPR_TO_MLIR_MODULE_EVENT):
# -> 2017   lowering_result = mlir.lower_jaxpr_to_module(
#    2018       module_name,
#    2019       closed_jaxpr,
#    2020       ordered_effects=ordered_effects,
#    2021       backend_or_name=backend,
#    2022       platforms=platforms,
#    2023       axis_context=axis_ctx,
#    2024       name_stack=name_stack,
#    2025       donated_args=donated_invars,
#    2026       replicated_args=replicated_args,
#    2027       arg_shardings=in_mlir_shardings,
#    2028       result_shardings=out_mlir_shardings,
#    2029       in_layouts=in_layouts,
#    2030       out_layouts=out_layouts,
#    2031       arg_names=jaxpr.debug_info and jaxpr.debug_info.arg_names,
#    2032       result_names=jaxpr.debug_info and jaxpr.debug_info.result_paths,
#    2033       num_replicas=nreps,
#    2034       num_partitions=num_partitions,
#    2035       all_default_mem_kind=all_default_mem_kind,
#    2036       input_output_aliases=inout_aliases,
#    2037       propagated_out_mem_kinds=propagated_out_mem_kinds,
#    2038       lowering_parameters=lowering_parameters)
#    2039 tuple_args = dispatch.should_tuple_args(len(global_in_avals), backend.platform)
#    2040 unordered_effects = list(
#    2041     effects.ordered_effects.filter_not_in(closed_jaxpr.effects))
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:952, in lower_jaxpr_to_module(***failed resolving arguments***)
#     950   attrs["mhlo.num_replicas"] = i32_attr(num_replicas)
#     951   attrs["mhlo.num_partitions"] = i32_attr(num_partitions)
# --> 952   lower_jaxpr_to_fun(
#     953       ctx, "main", jaxpr, ordered_effects,
#     954       name_stack=name_stack,
#     955       public=True,
#     956       replicated_args=replicated_args,
#     957       arg_shardings=arg_shardings,
#     958       result_shardings=result_shardings,
#     959       input_output_aliases=input_output_aliases,
#     960       xla_donated_args=xla_donated_args,
#     961       arg_names=arg_names,
#     962       result_names=result_names,
#     963       arg_memory_kinds=arg_memory_kinds,
#     964       result_memory_kinds=result_memory_kinds,
#     965       arg_layouts=in_layouts,
#     966       result_layouts=out_layouts,
#     967       propagated_out_mem_kinds=propagated_out_mem_kinds)
#     969 try:
#     970   if not ctx.module.operation.verify():
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1394, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, name_stack, public, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, api_name, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts, propagated_out_mem_kinds)
#    1392   callee_name_stack = name_stack
#    1393 consts = [ir_constants(xla.canonicalize_dtype(x)) for x in jaxpr.consts]
# -> 1394 out_vals, tokens_out = jaxpr_subcomp(
#    1395     ctx, jaxpr.jaxpr, callee_name_stack, tokens_in,
#    1396     consts, *args, dim_var_values=dim_var_values)
#    1397 outs = []
#    1398 for eff in effects:
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1545, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1542 in_nodes = map(read, eqn.invars)
#    1543 source_info = eqn.source_info.replace(
#    1544     name_stack=name_stack + eqn.source_info.name_stack)
# -> 1545 loc = _source_info_to_location(ctx, eqn.primitive, eqn.params, source_info)
#    1546 with (source_info_util.user_context(eqn.source_info.traceback), loc,
#    1547       eqn.ctx.manager):
#    1548   override_rule = get_override_lowering_rule(eqn.primitive)
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:402, in _source_info_to_location(ctx, primitive, params, source_info)
#     398 def _source_info_to_location(
#     399     ctx: ModuleContext, primitive: core.Primitive, params: dict[str, Any],
#     400     source_info: source_info_util.SourceInfo) -> ir.Location:
#     401   eqn_str = (f'{source_info.name_stack}/'
# --> 402              f'{core.str_eqn_compact(primitive.name, params)}')
#     403   if config.include_full_tracebacks_in_locations.value:
#     404     if source_info.traceback is None:
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/core.py:3347, in str_eqn_compact(primitive_name, params)
#    3345 def str_eqn_compact(primitive_name: str, params: dict) -> str:
#    3346   "Compact equation to string conversion used in HLO metadata."
# -> 3347   kvs = " ".join(f"{k}={v}" for k, v in params.items()
#    3348                  if _compact_eqn_should_include(k, v))
#    3349   return f"{primitive_name}[{kvs}]" if len(kvs) > 0 else primitive_name
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/core.py:3348, in <genexpr>(.0)
#    3345 def str_eqn_compact(primitive_name: str, params: dict) -> str:
#    3346   "Compact equation to string conversion used in HLO metadata."
#    3347   kvs = " ".join(f"{k}={v}" for k, v in params.items()
# -> 3348                  if _compact_eqn_should_include(k, v))
#    3349   return f"{primitive_name}[{kvs}]" if len(kvs) > 0 else primitive_name
#
# File /home/library/workspace/mlos/venvs/jax/lib/python3.10/site-packages/jax/_src/core.py:3339, in _compact_eqn_should_include(k, v)
#    3337 def _compact_eqn_should_include(k: str, v: Any) -> bool:
#    3338   if k == 'branches': return False
# -> 3339   if isinstance(v, (Jaxpr, ClosedJaxpr)): return False
#    3340   if (isinstance(v, tuple) and
#    3341       any(isinstance(e, (Jaxpr, ClosedJaxpr)) for e in v)):
#    3342     return False
#
# KeyboardInterrupt:
